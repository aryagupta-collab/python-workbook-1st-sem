# %%
<h3> Name - Arya Gupta
    Roll No - 20972
    College Name - AGC (SDBI)
    Class - F.Y. BSc Data Science
    Subject - Principles of Programming Language</h3>
# Out:
#   Cell In[22], line 1
#     <h3> Name - Arya Gupta
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h2>Assignment 2

# %% [markdown]
# <h2>set A

# %% [markdown]
# ## Q1 Count vowels

# %%
s=input('Enter string: ')
vowels='aeiouAEIOU'
count=0
for ch in s:
    if ch in vowels:
        count+=1
print('Vowels:',count)
# Out:
# Enter string:  ROHIT IS GOOD
# Vowels: 5

# %% [markdown]
# ## Q2 Palindrome

# %%
s=input('Enter string: ')
rev=s[::-1]
if s==rev:
    print('Palindrome')
else:
    print('Not Palindrome')
# Out:
# Enter string:  RAMA
# Not Palindrome

# %% [markdown]
# ## Q3 Reverse string

# %%
s=input('Enter string: ')
rev=''
for ch in s:
    rev=ch+rev
print('Reverse:',rev)
# Out:
# Enter string:  HELLO WORLD
# Reverse: DLROW OLLEH

# %% [markdown]
# ## Q4 Character frequency

# %%
s=input('Enter string: ')
freq={}
for ch in s:
    freq[ch]=freq.get(ch,0)+1
print(freq)
# Out:
# Enter string:  DUSTIN
# {'D': 1, 'U': 1, 'S': 1, 'T': 1, 'I': 1, 'N': 1}

# %% [markdown]
# ## Q5 Remove spaces

# %%
s=input('Enter string: ')
print(s.replace(' ',''))
# Out:
# Enter string:  arya gupta
# aryagupta

# %% [markdown]
# <h2>set B

# %% [markdown]
# <h2>1. First non‑repeating character

# %%
s = input("Enter string: ")
for ch in s:
 if s.count(ch) == 1:
    print(ch)
    break
# Out:
# Enter string:  apple
# a

# %% [markdown]
# <h2>2. Anagram check

# %%
a = input("Enter first string: ")
b = input("Enter second string: ")
if sorted(a) == sorted(b):
    print("Anagram")
else:
    print("Not Anagram")
# Out:
# Enter first string:  a
# Enter second string:  s
# Not Anagram

# %% [markdown]
# <h2>3. Title case without title()

# %%
s = input("Enter string: ")
words = s.split()
result = ""
for w in words:
   result += w[0].upper() + w[1:] + " "
print(result.strip())

# %% [markdown]
# <h2>4. Replace substring

# %%
s = "Python is easy"
print(s.replace("easy", "fun"))

# %% [markdown]
# <h2>SET C
#
# 1. Longest word

# %%
sentence = input("Enter sentence: ")
words = sentence.split()
print(max(words, key=len))

# %% [markdown]
# <h2>2. Digits / Alphabets / Both

# %%
s = input("Enter string: ")
if s.isdigit():
    print("Only digits")
elif s.isalpha():
    print("Only alphabets")
else:
    print("Both")
# Out:
# Enter string:  2345
# Only digits
